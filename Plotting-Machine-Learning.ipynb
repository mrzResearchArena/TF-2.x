# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/TF-2.x/blob/master/Plotting-Machine-Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot') # { ggplot, seaborn, bmh }
plt.rcParams.update({'font.size': 13})

# Reference: [https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html]

# %%
x = np.arange(0, 10, 0.25) # 0<10, increase by 1 (0, 0.25, 0.5, 0.75, ... 9.75)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %% [markdown]
# #### [1]. Drawing a General Plot:

# %%
plt.plot(x, np.sin(x), label='sin')
# plt.plot(x, np.sin(x), marker='o') #
plt.plot(x, np.cos(x), label='cos')
plt.legend()

plt.title('General Plot')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
#end

# %%
plt.plot(x, np.sin(x), label='sin')
# plt.plot(x, np.sin(x), marker='o') #
plt.plot(x, np.cos(x), label='cos')
plt.legend()

plt.title('General Plot')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
#end

# %% [markdown]
# #### [2]. Drawing a Sclatter Plot:

# %%
plt.scatter(x, np.sin(x), label='sin')
plt.scatter(x, np.cos(x), label='cos')
plt.legend()

plt.title('Sclatter Plot')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
# end

# %% [markdown]
# #### [3]. Drawing a General Plot and Sclatter Plot Together:

# %%
plt.scatter(x, np.sin(x), label='sin')
plt.plot(x, np.cos(x), label='cos')
plt.legend()

plt.title('Scaller Plot and General Plot Together')
plt.xlabel('Time')
plt.ylabel('Value')

plt.show()
# end

# %% [markdown]
# #### [4]. Bar Plot / Frequency Plot:

# %%
names  = ['A', 'C', 'G', 'T']
values = [10, 5, 14, 11] 

plt.bar(names, values)
plt.title('Frequency Plot')

plt.show()
# end

# %% [markdown]
# #### [5]. Pie Plot:

# %%
# Using above cell's data

plt.pie(x=values, labels=names, autopct='%.1f%%') #shadow=True

plt.legend()
plt.title('The percentage of single nucluotide')

plt.show()

# %% [markdown]
# #### [6]. Loss and Accuracy Plot:

# %%
def lossPlot(results):
    plt.title(label='Loss: Training and Validation')
    plt.plot(results.history['loss'], label='Training Loss')
    plt.plot(results.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#end-def

def accuracyPlot(results):
    plt.title(label='Accuracy: Training and Validation')
    plt.plot(results.history['accuracy'], label='Training Accuracy')
    plt.plot(results.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
#end-def

# %% [markdown]
# #### [7]. Exercise-1:

# %%
x = list(range(1,16))

y1 = [7.010334015,6.814743042,6.725479603,6.706170082,6.605310917,6.549385548,6.465535641,6.360852718,6.343966484,6.258212566,6.224091053,6.224159718,6.153710842,6.100941181,5.997457027]
y2 = [6.7990722656,6.6554851532,6.592318058,6.589597702,6.5175023079,6.4691357613,6.487112999,6.442671299,6.4103941917,6.4190573692,6.4226365089,6.409491539,6.421216011,6.4116587639,6.3990578651]
y3 = [6.7592525482,6.6308059692,6.5754742622,6.5181903839,6.5309948921,6.5518059731,6.5209336281,6.4646553993,6.4268374443,6.434387207,6.3809723854,6.3823962212,6.3597350121,6.3431911469,6.3297309875]
y4 = [6.6926531792,6.4849815369,6.2807383537,6.2026648521,6.1155114174,6.0339999199,5.9798088074,5.9018745422,5.859896183,5.8100652695,5.7939491272,5.7333316803,5.7264800072,5.7187709808,5.6422071457]
y5 = [6.900744915,6.623087883,6.4858279228,6.3752384186,6.2747387886,6.1746149063,6.0992035866,6.0854172707,6.0030112267,5.9537258148,5.9506406784,5.8522586823,5.8053441048,5.8180165291,5.7535595894]

# %%
plt.plot(x, y1, label='StTr_Aux_Pos_Fa', marker='.')

plt.plot(x, y2, label='Tr_Pos_vec', marker='.')

plt.plot(x, y3, label='Tr_vec', marker='.')

plt.plot(x, y4, label='Tr_vec_CNN_Bat', marker='.')

plt.plot(x, y5, label='StTr_Aux_vec_CNN_Bat', marker='.')


plt.legend()
plt.title('Transformer Plotting', fontsize=16)

plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss',  fontsize=12)

# plt.ylim(5.5, 7.5)
# plt.xlim(0, 15)

plt.savefig(fname='xyz-5.png', dpi=300)
plt.show()

# %%
Styles = ['default', 'ggplot', 'seaborn', 'bmh']

for style in Styles:
    plt.style.use(style)

    ### begin
    plt.plot(x, y1, label='StTr_Aux_Pos_Fa', marker='.')

    plt.plot(x, y2, label='Tr_Pos_vec', marker='.')

    plt.plot(x, y3, label='Tr_vec', marker='.')

    plt.plot(x, y4, label='Tr_vec_CNN_Bat', marker='.')

    plt.plot(x, y5, label='StTr_Aux_vec_CNN_Bat', marker='.')


    plt.legend()
    plt.title('Transformer Plotting', fontsize=16)

    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss',  fontsize=12)

    # plt.ylim(5.5, 7.5)
    # plt.xlim(0, 15)

    plt.savefig(fname='xyz-{}.png'.format(style), dpi=300)
    plt.show()
    ### end
