# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/TF-2.X/blob/master/Plotting_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 10, 0.25) # 0<10, increase by 1 (0, 0.25, 0.5, 0.75, ... 9.75)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %% [markdown]
# ## [1]. Drawing a general plot

# %%
plt.plot(x, np.sin(x), label='sin')
plt.plot(x, np.cos(x), label='cos')
plt.legend()
plt.title('General Plot')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
# end

# %% [markdown]
# ## [2]. Drawing a sclatter plot

# %%
plt.scatter(x, np.sin(x), label='sin')
plt.scatter(x, np.cos(x), label='cos')
plt.legend()
plt.title('Scaller Plot')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
# end

# %% [markdown]
# ## [3]. Drawing a General Plot and Sclatter Plot Together

# %%
plt.scatter(x, np.sin(x), label='sin')
plt.plot(x, np.cos(x), label='cos')
plt.legend()
plt.title('Scaller Plot and General Plot Together')
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()
# end

# %% [markdown]
# ## Histogram Plot

# %%
plt.hist([1, 2, 1, 1, 2, 3])
plt.show()
# end

# %%
plt.hist([50, 4500])
plt.show()
# end
